# %%
import numpy as np 
import pandas as pd
sample=pd.read_csv(r"C:\Users\neha4\Desktop\PIMS_2020_Real_Estate_data-master\PIMS_2020_Real_Estate_data-master\sample_clean.csv")
print("successfully read the file")
sample2=sample[sample.Year == 2017]
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
# Out:
# successfully read the file
# C:\Users\neha4\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
import matplotlib.pyplot as plt
import pandas as py
fig, ax = plt.subplots(figsize=(20,4))
plt.scatter(sample2["fsa"],sample2["av_saf2"])
ax.set_title('average safety of 2017 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(sample2["fsa"],sample2["pct_change"])
ax.set_title('percent change of 2017 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
sample2=sample[sample.Year == 2018]
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
# Out:
# C:\Users\neha4\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
import pandas as py
fig, ax = plt.subplots(figsize=(20,4))
plt.scatter(sample2["fsa"],sample2["av_saf2"])
ax.set_title('average safety of 2018 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(sample2["fsa"],sample2["pct_change"])
ax.set_title('percent change of 2018 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
sample2=sample[sample.Year == 2019]
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
# Out:
# C:\Users\neha4\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
import pandas as py
fig, ax = plt.subplots(figsize=(20,4))
plt.scatter(sample2["fsa"],sample2["av_saf2"])
ax.set_title('average safety of 2019 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(sample2["fsa"],sample2["pct_change"])
ax.set_title('percent change of 2019 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
sample2=sample[sample.Year == 2020]
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
# Out:
# C:\Users\neha4\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import matplotlib.pyplot as plt
import pandas as py
fig, ax = plt.subplots(figsize=(20,4))
plt.scatter(sample2["fsa"],sample2["av_saf2"])
ax.set_title('average safety of 2020 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(sample2["fsa"],sample2["pct_change"])
ax.set_title('percent change of 2019 grouped by fsa', fontsize = 'xx-large')
plt.savefig('plot.png', dpi=300, bbox_inches='tight')

# %%
import numpy as np 
import pandas as pd
sample=pd.read_csv(r"C:\Users\neha4\Desktop\PIMS_2020_Real_Estate_data-master\PIMS_2020_Real_Estate_data-master\sample_clean.csv")
print("successfully read the file")
sample2=sample
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
sample2.dropna(subset = ["saf1"], inplace=True)
sample2.dropna(subset = ["saf2"], inplace=True)
sample2.dropna(subset = ["saf3"], inplace=True)
sample2.dropna(subset = ["saf4"], inplace=True)
sample2.dropna(subset = ["saf5"], inplace=True)
sample2.dropna(subset = ["saf6"], inplace=True)
sample2.dropna(subset = ["saf7"], inplace=True)
sample2.dropna(subset = ["saf8"], inplace=True)
sample2.dropna(subset = ["YEAR_OF_CONSTRUCTION"], inplace=True)
sample2.dropna(subset = ["pct_change"], inplace=True)
sample2.dropna(subset = ["mr5y"], inplace=True)
sample2.dropna(subset = ["ASSESSED_VALUE"], inplace=True)
# Out:
# successfully read the file

# %%
A= sample2[['YEAR_OF_CONSTRUCTION','mr5y','saf1','saf2','saf3','saf4','saf5','saf6','saf7','saf8']]
B = sample2["ASSESSED_VALUE"]
new_header = A.iloc[0] #grab the first row for the header
A = A[1:] #take the data less the header row
B.columns = new_header #set the header row as the df header
new_header = B.iloc[0] #grab the first row for the header
B = B[1:] #take the data less the header row
B.columns = new_header #set the header row as the df header
X = A
y = B

# %%
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn import datasets, linear_model, metrics 
  

# defining feature matrix(X) and response vector(y) 

X = A
y = B
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, 
                                                    random_state=1) 
  
# create linear regression object 
reg = linear_model.LinearRegression() 
  
# train the model using the training sets 
reg.fit(X_train, y_train) 
  
# regression coefficients 
print('Coefficients: \n', reg.coef_) 
  
# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test))) 
  
# plot for residual error 
  
## setting plot style 
plt.style.use('fivethirtyeight') 
plt.figure(figsize=(40,20))
  
## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "green", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 
#fig, ax = plt.subplots(figsize=(20,4))
  
## plotting legend 
plt.legend(loc = 'upper right') 
#plt.figure(figsize=(20,20))  
## plot title 
plt.title("Residual Error") 

plt.savefig('plot.png', dpi=300, bbox_inches='tight')
  
## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [-7.99946661e+02 -4.37838958e+04 -9.91372623e+00  7.87880340e+02
#   9.83416252e+02  1.19789899e+03 -8.72030100e+02 -7.57370070e+02
#  -4.00134379e+02  5.88287930e+02]
# Variance score: 0.04487842937773612

# %%
import numpy as np 
import pandas as pd
sample=pd.read_csv(r"C:\Users\neha4\Desktop\PIMS_2020_Real_Estate_data-master\PIMS_2020_Real_Estate_data-master\sample_clean.csv")
print("successfully read the file")
sample2=sample
sum_column=(sample2["saf1"]+sample2["saf2"]+sample2["saf3"]+sample2["saf4"]+sample2["saf5"]+sample2["saf6"]+sample2["saf7"]+sample2["saf8"])/8
sample2["av_saf2"]=sum_column
sample2=sample2.sort_values(by='av_saf2',ascending=False)
sample2.dropna(subset = ["av_saf2"], inplace=True)
sample2.dropna(subset = ["YEAR_OF_CONSTRUCTION"], inplace=True)
sample2.dropna(subset = ["pct_change"], inplace=True)
sample2.dropna(subset = ["mr5y"], inplace=True)
sample2.dropna(subset = ["ASSESSED_VALUE"], inplace=True)
A= sample2[['av_saf2','YEAR_OF_CONSTRUCTION','mr5y']]
B = sample2["ASSESSED_VALUE"]
new_header = A.iloc[0] #grab the first row for the header
A = A[1:] #take the data less the header row
B.columns = new_header #set the header row as the df header
new_header = B.iloc[0] #grab the first row for the header
B = B[1:] #take the data less the header row
B.columns = new_header #set the header row as the df header
X = A
y = B
# Out:
# successfully read the file

# %%
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn import datasets, linear_model, metrics 
  
# load the boston dataset 
#boston = datasets.load_boston(return_X_y=False) 
  
# defining feature matrix(X) and response vector(y) 

X = A
y = B
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, 
                                                    random_state=1) 
  
# create linear regression object 
reg = linear_model.LinearRegression() 
  
# train the model using the training sets 
reg.fit(X_train, y_train) 
  
# regression coefficients 
print('Coefficients: \n', reg.coef_) 
  
# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test))) 
  
# plot for residual error 
  
## setting plot style 
plt.style.use('fivethirtyeight') 
plt.figure(figsize=(40,20))
  
## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "green", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 
  
## plotting legend 
plt.legend(loc = 'upper right') 
  
## plot title 
plt.title("multiple linear regression with features as average safety,mortgage rate and year ofconstruction with the response as assessment value") 

plt.savefig('plot.png', dpi=300, bbox_inches='tight')
  
## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [ -142.69353271 -1162.70376557 28286.69454227]
# Variance score: 0.006216081572001374

# %%
import os
os.system("pip install pandas")
os.system("pip install matlab")
os.system("pip install seaborn")
os.system("pip install sklearn")
import matplotlib as mpl
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sea
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
s=pd.read_csv(r"C:\Users\neha4\Desktop\PIMS_2020_Real_Estate_data-master\PIMS_2020_Real_Estate_data-master\New_sample_clean.csv")
print("successfully read the file")
sample=s[['ASSESSED_VALUE','mr5y','Inflation', 'Year', 'pct_change', 'YEAR_OF_CONSTRUCTION','saf1', 'saf2', 'saf3','saf4','saf5','saf6','saf7','saf8','walk_score_comm','transit_score_comm','bike_score_comm','own1','own2','own3','lab1','lab2','lab3','inc1','inc2','inc3','inc4','pop1','pop2','pop3','pop4','pop5','pop6']]
X=sample.copy()
X=X.drop(axis=1,columns=['pct_change'])
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(X.mean(), inplace=True)
Y = sample['pct_change']
#sample['pct_change']
# Out:
# successfully read the file

# %%
fvalue_selector = SelectKBest(f_classif,k=5)

# Apply the SelectKBest object to the features and target
X_kbest = fvalue_selector.fit_transform(X, Y)

# %%
print('Original number of features:', X.shape[1])
print('Reduced number of features:', X_kbest.shape[1])
# Out:
# Original number of features: 32
# Reduced number of features: 5

# %%
fvalue_selector.get_support([29])
X_new = fvalue_selector.transform(X)
X.columns[fvalue_selector.get_support(indices=True)]
# Out:
# Index(['ASSESSED_VALUE', 'mr5y', 'Inflation', 'YEAR_OF_CONSTRUCTION', 'lab1'], dtype='object')

# %%
fvalue_selector = SelectKBest(f_classif,k=10)

# Apply the SelectKBest object to the features and target
X_kbest = fvalue_selector.fit_transform(X, Y)

# %%
print('Original number of features:', X.shape[1])
print('Reduced number of features:', X_kbest.shape[1])
# Out:
# Original number of features: 32
# Reduced number of features: 10

# %%
fvalue_selector.get_support([29])
X_new = fvalue_selector.transform(X)
X.columns[fvalue_selector.get_support(indices=True)]
# Out:
# Index(['ASSESSED_VALUE', 'mr5y', 'Inflation', 'YEAR_OF_CONSTRUCTION', 'saf3',
#        'own1', 'lab1', 'lab3', 'inc3', 'pop6'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import io
import json
import requests



def transformed_data():


    url = 'https://raw.githubusercontent.com/shughestr/PIMS_2020_Real_Estate_data/master/sample_clean.csv'
    df = pd.read_csv(url, error_bad_lines=False)




### Normalise absolute value of crime variables and income recipients by the respective population 

    for col in ['saf1','saf2','saf3','saf4','saf5','saf6','saf7','saf8','inc2']:
        df[col] = 100 * df[col] / df['pop1'] 




### Adding vacancy rate column from other census dataset

    data2 = requests.get('https://data.calgary.ca/resource/set9-futw.json')
    df2 = pd.DataFrame(json.loads(data2.text))

    df2 = df2.loc[df2['dwelling_type_code'].isin([str(x) for x in range(1,11)])]

    df2 = df2.drop(labels = ['census_year', 'community','ward','dwelling_type','dwelling_type_code','dwelling_type_description'],axis=1)

    df2[['dwelling_cnt', 'resident_cnt', 'ocpd_dwelling_cnt',
       'vacant_dwelling_cnt', 'ocpd_ownership_cnt', 'renovation_dwelling_cnt',
       'under_const_dwelling_cnt', 'inactive_cnt', 'other_purpose_cnt']] = df2[['dwelling_cnt', 'resident_cnt', 'ocpd_dwelling_cnt',
       'vacant_dwelling_cnt', 'ocpd_ownership_cnt', 'renovation_dwelling_cnt',
       'under_const_dwelling_cnt', 'inactive_cnt', 'other_purpose_cnt']].astype(int)

    df2=df2.groupby(['code']).sum()

    df2['vacancy_rate'] = df2['vacant_dwelling_cnt']/(df2['vacant_dwelling_cnt']+df2['ocpd_dwelling_cnt']) * 100

    df2vac = df2['vacancy_rate']

    vacdict = df2vac.to_dict()

    df['vacancy_rate'] = 0

    for x in vacdict:
        df['vacancy_rate'] = np.where(df['COMM_CODE']==x, vacdict[x],df['vacancy_rate'])
    url = 'https://raw.githubusercontent.com/neha0812/BCFFSA-project/master/walk_score.csv'
    df3 = pd.read_csv(url, error_bad_lines=False)
# making the entries of both the csv files in lowercase for mapping purpose.
    df = df.apply(lambda x: x.str.lower() if x.dtype == "object" else x)  
    df3 = df3.apply(lambda x: x.str.lower() if x.dtype == "object" else x)  
    df3 = df3.set_index('Name')
#Adding walk score, bike score, transit score and population for different community in calgary
    df['walk_score_comm'] = df['COMM_NAME'].map(df3['Walk Score'])
    df['transit_score_comm'] = df['COMM_NAME'].map(df3['Transit Score'])
    df['bike_score_comm'] = df['COMM_NAME'].map(df3['Bike Score'])
    df['comm_polulation'] = df['COMM_NAME'].map(df3['Population'])    
    return df
df= transformed_data()
df
# Out:
#                              ADDRESS  ASSESSED_VALUE ASSESSMENT_CLASS  \
# 0                 4 saddlemead rd ne        343500.0               re
# 1                 4 saddlemead rd ne        345500.0               re
# 2                 4 saddlemead rd ne        323500.0               re
# 3                 4 saddlemead rd ne        315500.0               re
# 4                70 saddleback rd ne        393500.0               re
# 5                70 saddleback rd ne        397000.0               re
# 6                70 saddleback rd ne        390000.0               re
# 7                70 saddleback rd ne        382500.0               re
# 8                81 saddlehorn cr ne        524000.0               re
# 9                81 saddlehorn cr ne        530000.0               re
# 10               81 saddlehorn cr ne        524000.0               re
# 11               81 saddlehorn cr ne        514500.0               re
# 12              69 saddlecreek cr ne        467500.0               re
# 13              69 saddlecreek cr ne        468500.0               re
# 14              69 saddlecreek cr ne        462000.0               re
# 15              69 saddlecreek cr ne        452000.0               re
# 16              50 saddlecreek cr ne        410500.0               re
# 17              50 saddlecreek cr ne        411000.0               re
# 18              50 saddlecreek cr ne        405000.0               re
# 19              50 saddlecreek cr ne        396000.0               re
# 20                 13 taraglen rd ne        301000.0               re
# 21                 13 taraglen rd ne        296500.0               re
# 22                 13 taraglen rd ne        288000.0               re
# 23                 13 taraglen rd ne        280000.0               re
# 24                 55 taraglen rd ne        327000.0               re
# 25                 55 taraglen rd ne        324500.0               re
# 26                 55 taraglen rd ne        316500.0               re
# 27                 55 taraglen rd ne        309500.0               re
# 28              32 martingrove me ne        370000.0               re
# 29              32 martingrove me ne        376000.0               re
# ...                              ...             ...              ...
# 15970               70 chapman wy se        508500.0               re
# 15971               70 chapman wy se        485500.0               re
# 15972       118 chapalina park cr se        477000.0               re
# 15973       118 chapalina park cr se        492500.0               re
# 15974       118 chapalina park cr se        497500.0               re
# 15975       118 chapalina park cr se        469500.0               re
# 15976  1103 11 chaparral ridge dr se        171000.0               re
# 15977  1103 11 chaparral ridge dr se        164000.0               re
# 15978  1103 11 chaparral ridge dr se        160000.0               re
# 15979  1103 11 chaparral ridge dr se        141500.0               re
# 15980  103v 11 chaparral ridge dr se         10000.0               re
# 15981  103v 11 chaparral ridge dr se         10000.0               re
# 15986             60.0           10,088
# 15987             60.0           10,088
# 15988             60.0           10,088
# 15989             60.0           10,088
# 15990             60.0           10,088
# 15991             60.0           10,088
# 15992             60.0           10,088
# 15993             60.0           10,088
# 15994             60.0           10,088
# 15995             60.0           10,088
# 15996             60.0           10,088
# 15997             60.0           10,088
# 15998             60.0           10,088
# 15999             60.0           10,088
#
# [16000 rows x 48 columns]

# %%
data_regression=df[['mr5y','Inflation', 'pct_change', 'YEAR_OF_CONSTRUCTION','saf1', 'saf2', 'saf3','saf4','saf5','saf6','saf7','saf8','walk_score_comm','transit_score_comm','bike_score_comm','own1','own2','own3','lab1','lab2','lab3','inc1','inc2','inc3','inc4','pop1','pop2','pop3','pop4','pop5','pop6','vacancy_rate']]
data_regression.dropna(inplace=True)
X_r=data_regression.drop('pct_change',axis=1).values
y_r=data_regression['pct_change'].values
names=data_regression.drop('pct_change',axis=1).columns
# Out:
# C:\Users\neha4\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt
names=data_regression.drop('pct_change',axis=1).columns
print(names)
# Out:
# Index(['mr5y', 'Inflation', 'YEAR_OF_CONSTRUCTION', 'saf1', 'saf2', 'saf3',
#        'saf4', 'saf5', 'saf6', 'saf7', 'saf8', 'walk_score_comm',
#        'transit_score_comm', 'bike_score_comm', 'own1', 'own2', 'own3', 'lab1',
#        'lab2', 'lab3', 'inc1', 'inc2', 'inc3', 'inc4', 'pop1', 'pop2', 'pop3',
#        'pop4', 'pop5', 'pop6', 'vacancy_rate'],
#       dtype='object')

# %%
#performing Lasso on the above features by normalising the data, note alpha ==0.001
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X_r)
from sklearn.linear_model import Lasso
import matplotlib.pyplot as plt
names=data_regression.drop('pct_change',axis=1).columns
print(names)
lasso=Lasso(alpha=0.001)
lasso_coef=lasso.fit(X,y_r).coef_
_=plt.figure(figsize=(40,20))
_=plt.plot(range(len(names)),lasso_coef)
_=plt.xticks(range(len(names)),names,rotation=60)
_=plt.ylabel("Coefficients")
plt.show()  
X
# Out:
# Index(['mr5y', 'Inflation', 'YEAR_OF_CONSTRUCTION', 'saf1', 'saf2', 'saf3',
#        'saf4', 'saf5', 'saf6', 'saf7', 'saf8', 'walk_score_comm',
#        'transit_score_comm', 'bike_score_comm', 'own1', 'own2', 'own3', 'lab1',
#        'lab2', 'lab3', 'inc1', 'inc2', 'inc3', 'inc4', 'pop1', 'pop2', 'pop3',
#        'pop4', 'pop5', 'pop6', 'vacancy_rate'],
#       dtype='object')
# array([[-1.26968248, -0.17440972,  0.97805115, ..., -0.58302838,
#         -1.96485116,  1.88315049],
#        [ 1.21017119,  1.14615189,  0.97805115, ..., -0.58302838,
#         -1.96485116,  1.88315049],
#        [ 0.71203464,  0.55187421,  0.97805115, ..., -0.58302838,
#         -1.96485116,  1.88315049],
#        ...,
#        [ 1.21017119,  1.14615189,  1.08677241, ..., -0.71803312,
#         -2.07154962, -0.33380418],
#        [ 0.71203464,  0.55187421,  1.08677241, ..., -0.71803312,
#         -2.07154962, -0.33380418],
#        [-0.61632947, -1.57001986,  1.08677241, ..., -0.71803312,
#         -2.07154962, -0.33380418]])
